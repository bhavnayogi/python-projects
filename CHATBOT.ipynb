# %%
import time 

print("Hello, Madam/Sir! You are talking to a PIZZA DELIVERY CHATBOT")
time.sleep(1)
print("May I know your good name?")
time.sleep(1)
name=input()
time.sleep(0.5)
print("How can we help you", name, "?")
print("1. I want to place an order. \n2. I want to see the Menu. \n3. I want a refund for the order I cancelled. \n4. I want to order the best seller pizza.")
time.sleep(1)
a=input()
time.sleep(1)
if a == "1":
    print("Sure", name)
    print("What would you like to have", name,"?")
    b=input()
    if b == b:
        time.sleep(1)
        print("Yummy Choice", name, ",\n YOUR ORDER AMOUNT IS Rs.250. \n How would you like to pay? (Cash on Delivery / UPI)")
        c=input()
        if c=="cash on delivery":
            time.sleep(1)
            print("THANK YOU FOR ORDERING. \n WE HAVE RECIEVED YOUR ORDER. IT WILL BE DELIVERED WITHIN 30 MINUTES. KINDLY PAY THE ORDER AMOUNT TO THE DELIVERY PARTNER  ")
        elif c=="upi":
            time.sleep(1)
            print("WE HAVE SENT YOU A REQUEST ON YOUR UPI. PLEASE PAY THE ORDER AMOUNT i.e Rs.250. If done, then type 'paid'. ")
            d=input()
            if d=="paid":
                time.sleep(1)
                print("THANK YOU FOR ORDERING. \n WE HAVE RECIEVED YOUR ORDER. IT WILL BE DELIVERED WITHIN 30 MINUTES.")
            elif d!="paid":
                time.sleep(1)
                print("Sorry we have not recieved your payment. Kindely restart the bot to order again.")


elif a== "2":
    print("Sure", name, "The menu will be displayed shortly")
    time.sleep(3)
    print("Margherita, Cheese n Corn, Cheese n Tomato, Moroccan Spice, Achari Do Pyaza, Fresh Veggie 7, Double Cheese Margherita, \nFarmhouse, Mexican Green Wave, Veggie Paradise, Peppy Paneer, Creamy Tomato, Delux Veggie, Veg Extravaganza, \nIndi Tandoori Paneer, Paneer Makhani, 5 Pepper, Unthinkable Pizza, Kadhai Paneer, 4 Cheese Pizza, \nCheese Dominator, Chicken Sausage, Keema Do Pyaza, Pepper Barbeque Chicken, Moroccan Spice, Pepper BBQ Chicken & Onion, \nCreamy Tomato, Chicken Fiesta, Chicken Golden Delight, Chicken Dominator, Non-veg Supreme, Chicken Pepperoni, Indi Chicken Tikka")
    time.sleep(5)
    print("Would you like to order something?")
    e=input()
    if e == "yes" :
        print("Sure", name, ". What would you like to order?")
        f=input()
        if f==f:
            time.sleep(1)
            print("Yummy Choice", name, ",\n YOUR ORDER AMOUNT IS Rs.250. \n How would you like to pay? (Cash on Delivery / UPI)")
            g=input()
        if g=="cash on delivery":
            time.sleep(1)
            print("THANK YOU FOR ORDERING. \n WE HAVE RECIEVED YOUR ORDER. IT WILL BE DELIVERED WITHIN 30 MINUTES. KINDLY PAY THE ORDER AMOUNT TO THE DELIVERY PARTNER  ")
        elif g=="upi":
            time.sleep(1)
            print("WE HAVE SENT YOU A REQUEST ON YOUR UPI. PLEASE PAY THE ORDER AMOUNT i.e Rs.250. If done, then type 'paid'. ")
            h=input()
            if h=="paid":
                time.sleep(1)
                print("THANK YOU FOR ORDERING. \n WE HAVE RECIEVED YOUR ORDER. IT WILL BE DELIVERED WITHIN 30 MINUTES.")
            elif h!="paid":
                time.sleep(1)
                print("Sorry we have not recieved your payment. Kindely restart the bot to order again.")

                   
elif a=="3":
    print("Sure", name,", what was was refund amount?")
    i=int(input())
    if i==i:
        time.sleep(1)
        print("Your refund amount i.e", i, "will be refunded directly into your bank account in 2-3 business days.")
        print("We hope we helped you out. Thankyou!")
    else:
        print("Enter the value in numbers only")
        

elif a=="4":
    time.sleep(1)
    print("Sure",name,"Our best seller pizza is the 4 CHEESE PIZZA. You sure you want to order it? ")
    j=input()
    if j=="yes":
        time.sleep(1)
        print("Yummy Choice", name, ",\n YOUR ORDER AMOUNT IS Rs.250. \n How would you like to pay? (Cash on Delivery / UPI)")
        g=input()
        if g=="cash on delivery":
            time.sleep(1)
            print("THANK YOU FOR ORDERING. \n WE HAVE RECIEVED YOUR ORDER. IT WILL BE DELIVERED WITHIN 30 MINUTES. KINDLY PAY THE ORDER AMOUNT TO THE DELIVERY PARTNER  ")
        elif g=="upi":
            time.sleep(1)
            print("WE HAVE SENT YOU A REQUEST ON YOUR UPI. PLEASE PAY THE ORDER AMOUNT i.e Rs.250. If done, then type 'paid'. ")
            h=input()
            if h=="paid":
                time.sleep(1)
                print("THANK YOU FOR ORDERING. \n WE HAVE RECIEVED YOUR ORDER. IT WILL BE DELIVERED WITHIN 30 MINUTES.")
            elif h!="paid":
                time.sleep(1)
                print("Sorry we have not recieved your payment. Kindely restart the bot to order again.")
    elif j=="no":
        time.sleep(1)
        print("Okay. If you want to order something else or wants to see the menu please restart the bot.")
        print("THANKYOU!")
        
        
else:
    print("Please enter one of the above options.")
    print("RESTART THE BOT. THANKYOU.")
# Out:
# Hello, Madam/Sir! You are talking to a PIZZA DELIVERY CHATBOT
# May I know your good name?
# bhavna
# How can we help you bhavna ?
# 1. I want to place an order.
# 2. I want to see the Menu.
# 3. I want a refund for the order I cancelled.
# 4. I want to order the best seller pizza.
# 4
# Sure bhavna Our best seller pizza is the 4 CHEESE PIZZA. You sure you want to order it?
# yes
# Yummy Choice bhavna ,
#  YOUR ORDER AMOUNT IS Rs.250.
#  How would you like to pay? (Cash on Delivery / UPI)
# upi
# WE HAVE SENT YOU A REQUEST ON YOUR UPI. PLEASE PAY THE ORDER AMOUNT i.e Rs.250. If done, then type 'paid'.
# paid
# THANK YOU FOR ORDERING.
#  WE HAVE RECIEVED YOUR ORDER. IT WILL BE DELIVERED WITHIN 30 MINUTES.
